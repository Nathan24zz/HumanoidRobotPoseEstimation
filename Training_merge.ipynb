# %%
# !python src/main.py --config experiments/train_merge_2.yaml --output_dir ichiro_nimbro_merge --dataset_path dataset/hrp/
# Out:
# BATCH_SIZE: 16
# DATASET:
#   FLIP: 0.5
#   INPUT_SIZE: [384, 384]
#   MAX_NUM_DETECTIONS: 10
#   MEAN: (0.485, 0.456, 0.406)
#   NUM_KEYPOINTS: 6
#   NUM_LIMBS: 5
#   OUTPUT_SIZE: [192, 192]
#   ROTATION: 40
#   SCALE: [0.5, 1.5]
#   SIGMA: 2.0
#   STD: (0.229, 0.224, 0.225)
#   TEST: merge_val_2
#   TRAIN: merge_train_2
#   TRANSLATE: 0.4
# DEVICE: cuda
# LOSS:
#   USE_WEIGHT: True
# MODE: hm
# MODEL:
#   BACKBONE: resnet18
#   FINAL_KERNEL: 3
#   NUM_SCALES: 2
#   PRETRAINED: True
# NUM_EPOCHS: 200
# NUM_WORKERS: 2
# PIN_MEMORY: False
# PRINT_FREQ: 100
# SEED: 42
# TEST:
#   DETECTION_THRESHOLD: 0.1
#   KEEP_RATIO: True
#   LIMB:
#     CONNECTION_RATIO: 0.8
#     CONNECTION_TOLERANCE: 0.7
#     DELETE_SHARED_PARTS: False
#     IGNORE_FEW_PARTS: False
#     LENGTH_RATE: 16
#     MIN_MEAN_SCORE: 0.2
#     MIN_NUM_CONNECTED_PARTS: 3
#     NUM_MIDPOINTS: 20
#     THRESHOLD: 0.05
#   NMS_KERNEL: 3
#   PROJECT: True
# TRAIN:
#   LR: 0.0001
#   LR_FACTOR: 0.0
#   LR_STEPS: []
# ...

# %%
# !python src/main.py --eval --config experiments/test_merge_2.yaml --dataset_path dataset/hrp/ --checkpoint ichiro_nimbro_merge/checkpoint.pth
# Out:
# BATCH_SIZE: 1
# DATASET:
#   FLIP: 0.5
#   INPUT_SIZE: [384, 384]
#   MAX_NUM_DETECTIONS: 10
#   MEAN: (0.485, 0.456, 0.406)
#   NUM_KEYPOINTS: 6
#   NUM_LIMBS: 5
#   OUTPUT_SIZE: [192, 192]
#   ROTATION: 30
#   SCALE: [0.75, 1.25]
#   SIGMA: 2.0
#   STD: (0.229, 0.224, 0.225)
#   TEST: merge_test_2
#   TRAIN: merge_train_2
#   TRANSLATE: 0.4
# DEVICE: cuda
# LOSS:
#   USE_WEIGHT: False
# MODE: hm
# MODEL:
#   BACKBONE: resnet18
#   FINAL_KERNEL: 3
#   NUM_SCALES: 2
#   PRETRAINED: True
# NUM_EPOCHS: 1
# NUM_WORKERS: 2
# PIN_MEMORY: False
# PRINT_FREQ: 1
# SEED: -1
# TEST:
#   DETECTION_THRESHOLD: 0.1
#   KEEP_RATIO: True
#   LIMB:
#     CONNECTION_RATIO: 0.8
#     CONNECTION_TOLERANCE: 0.7
#     DELETE_SHARED_PARTS: False
#     IGNORE_FEW_PARTS: False
#     LENGTH_RATE: 16
#     MIN_MEAN_SCORE: 0.2
#     MIN_NUM_CONNECTED_PARTS: 3
#     NUM_MIDPOINTS: 20
#     THRESHOLD: 0.05
#   NMS_KERNEL: 3
#   PROJECT: True
# TRAIN:
#   LR: 0.001
#   LR_FACTOR: 0.0
#   LR_STEPS: []
# ...
